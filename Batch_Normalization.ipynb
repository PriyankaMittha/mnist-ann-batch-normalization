# %% [markdown]
# # Model 1: Without Batch Normalization

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
# Out:
# WARNING:tensorflow:From C:\Users\swami\.conda\envs\tf_env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load and preprocess the data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape((X_train.shape[0], -1)) / 255.0
X_test = X_test.reshape((X_test.shape[0], -1)) / 255.0

# %%
# Define Model 1: Simple Feedforward Neural Network
model1 = Sequential([
    Dense(32, activation = 'relu', input_shape = (784,)),
    Dense(32, activation = 'relu'),
    Dense(10, activation = 'softmax')
])
# Out:
# WARNING:tensorflow:From C:\Users\swami\.conda\envs\tf_env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Compile Model 1
model1.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\swami\.conda\envs\tf_env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Print Model 1 summary
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                25120
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 26506 (103.54 KB)
# Trainable params: 26506 (103.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train Model 1
model1.fit(X_train, y_train, epochs = 10, batch_size = 32, validation_split = 0.1)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\swami\.conda\envs\tf_env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\swami\.conda\envs\tf_env\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1688/1688 [==============================] - 9s 4ms/step - loss: 0.3499 - accuracy: 0.8977 - val_loss: 0.1729 - val_accuracy: 0.9528
# Epoch 2/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1730 - accuracy: 0.9484 - val_loss: 0.1335 - val_accuracy: 0.9610
# Epoch 3/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.1323 - accuracy: 0.9597 - val_loss: 0.1261 - val_accuracy: 0.9620
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1116 - accuracy: 0.9667 - val_loss: 0.1231 - val_accuracy: 0.9647
# Epoch 5/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0965 - accuracy: 0.9707 - val_loss: 0.1195 - val_accuracy: 0.9660
# Epoch 6/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0861 - accuracy: 0.9733 - val_loss: 0.1048 - val_accuracy: 0.9702
# Epoch 7/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0779 - accuracy: 0.9758 - val_loss: 0.1117 - val_accuracy: 0.9703
# Epoch 8/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0700 - accuracy: 0.9774 - val_loss: 0.1167 - val_accuracy: 0.9677
# Epoch 9/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0639 - accuracy: 0.9799 - val_loss: 0.1128 - val_accuracy: 0.9720
# Epoch 10/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.0589 - accuracy: 0.9813 - val_loss: 0.1076 - val_accuracy: 0.9722

# %%
# Evaluate Model 1
test_loss, test_acc = model1.evaluate(X_test, y_test)
print("Model 1 - Test accuracy:", test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1194 - accuracy: 0.9661
# Model 1 - Test accuracy: 0.9660999774932861

# %% [markdown]
# # Model 2: Deep Learning Model with Batch Normalization

# %%
# Define Model 2: Model with Batch Normalization
model2 = Sequential([
    Dense(32, activation = 'relu', input_shape = (784,)),
    BatchNormalization(), # Adding Batch Normalization Layer
    Dense(32, activation = 'relu'),
    BatchNormalization(), # Adding Batch Normalization Layer
    Dense(10, activation = 'softmax')
])

# %%
# Compile Model 2
model2.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

# %%
# Print Model 2 summary
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 32)                25120
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_5 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 26762 (104.54 KB)
# Trainable params: 26634 (104.04 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %%
# Train Model 2
model2.fit(X_train, y_train, epochs = 10, batch_size = 32, validation_split = 0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 11s 5ms/step - loss: 0.3831 - accuracy: 0.8882 - val_loss: 0.1565 - val_accuracy: 0.9533
# Epoch 2/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1951 - accuracy: 0.9408 - val_loss: 0.1229 - val_accuracy: 0.9647
# Epoch 3/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1568 - accuracy: 0.9518 - val_loss: 0.0996 - val_accuracy: 0.9713
# Epoch 4/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1373 - accuracy: 0.9584 - val_loss: 0.1017 - val_accuracy: 0.9695
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1257 - accuracy: 0.9607 - val_loss: 0.1016 - val_accuracy: 0.9698
# Epoch 6/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1127 - accuracy: 0.9651 - val_loss: 0.1003 - val_accuracy: 0.9702
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1045 - accuracy: 0.9666 - val_loss: 0.0863 - val_accuracy: 0.9743
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1003 - accuracy: 0.9678 - val_loss: 0.0964 - val_accuracy: 0.9718
# Epoch 9/10
# 1688/1688 [==============================] - 11s 6ms/step - loss: 0.0923 - accuracy: 0.9708 - val_loss: 0.0912 - val_accuracy: 0.9745
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.0916 - accuracy: 0.9710 - val_loss: 0.0911 - val_accuracy: 0.9752

# %%
# Evaluate Model 2
test_loss, test_acc = model2.evaluate(X_test, y_test)
print("Model 1 - Test accuracy:", test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1051 - accuracy: 0.9666
# Model 1 - Test accuracy: 0.9666000008583069

# %% [markdown]
# # 📌 Conclusion:
#
# Batch Normalization significantly improves model performance by stabilizing learning and accelerating convergence.
#
# It is an essential technique for building efficient deep learning models.
